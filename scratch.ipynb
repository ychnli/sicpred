# %%
import xarray as xr
import numpy as np 
import os
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset("/scratch/users/yucli/cesm_data/icethick/icethick_r6i1301p1f1.nc")
ds["icethick"].isel(time=-5).plot(vmin=0, vmax=5)
